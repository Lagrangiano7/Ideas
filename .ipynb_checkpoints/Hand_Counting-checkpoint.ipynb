# %% [markdown]
# **Idea:** we can use the fingers of one hand to count up to $32$ (or $31$ if we consider 0, which is not typically done) and up to $2^{10}$ using both hands. This is simply binary, where each finger represents a given position
